# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io
import os 
import tqdm
import glob
import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import gray2rgb

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.densenet import DenseNet169
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# ### IMPORT / VIEWING / PREPROCESSING DATASET

# %% [markdown]
# > `DATA AUGMENTATION`

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=30,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   validation_split = 0.2)

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 128)
# Out:
# Found 4098 images belonging to 4 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 128)
# Out:
# Found 1023 images belonging to 4 classes.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 5, figsize=(20,20))

for i in tqdm(range(0,5)):
    rand1 = np.random.randint(len(train_dataset))
    rand2 = np.random.randint(100)
    ax[i].imshow(train_dataset[rand1][0][rand2])
    ax[i].axis('off')
    a = train_dataset[rand1][1][rand2]
    if a[0] == 1:
        ax[i].set_title('Mild Dementia')
    elif a[1] == 1:
        ax[i].set_title('Moderate Dementia')
    elif a[2] == 1:
        ax[i].set_title('Non Demetia')
    elif a[3] == 1:
        ax[i].set_title('Very Mild Dementia')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:13<00:00,  2.71s/it]

# %% [markdown]
# ### MODEL BUILDING

# %%
# Model Initialization

base_model = DenseNet169(input_shape=(224,224,3), 
                         include_top=False,
                         weights="imagenet")

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(2048,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4,activation='softmax'))

# %%
# Summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 7, 7, 1664)        12642880
#
#  dropout (Dropout)           (None, 7, 7, 1664)        0
#
#  flatten (Flatten)           (None, 81536)             0
#
#  batch_normalization (BatchN  (None, 81536)            326144
#  ormalization)
#
#  dense (Dense)               (None, 2048)              166987776
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  activation (Activation)     (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  activation_1 (Activation)   (None, 1024)              0
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 182,071,364
# Trainable params: 169,259,268
# Non-trainable params: 12,812,096
# _________________________________________________________________

# %%
# Model Compile 

OPT    = tensorflow.keras.optimizers.Adam(lr=0.001)

model.compile(loss='categorical_crossentropy',
              metrics=[tensorflow.keras.metrics.AUC(name = 'auc')],
              optimizer=OPT)
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Defining Callbacks

filepath = './best_weights.hdf5'

earlystopping = EarlyStopping(monitor = 'val_auc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'val_auc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)


callback_list = [earlystopping, checkpoint]

# %%
model_history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 500,
                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/500
# 33/33 [==============================] - ETA: 0s - loss: 0.7322 - auc: 0.9068
# Epoch 1: val_auc did not improve from 0.81969
# 33/33 [==============================] - 571s 17s/step - loss: 0.7322 - auc: 0.9068 - val_loss: 1.2542 - val_auc: 0.8042
# Epoch 2/500
# 33/33 [==============================] - ETA: 0s - loss: 0.7167 - auc: 0.9080
# Epoch 2: val_auc improved from 0.81969 to 0.83385, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 569s 17s/step - loss: 0.7167 - auc: 0.9080 - val_loss: 1.0465 - val_auc: 0.8338
# Epoch 3/500
# 33/33 [==============================] - ETA: 0s - loss: 0.7008 - auc: 0.9115
# Epoch 3: val_auc did not improve from 0.83385
# 33/33 [==============================] - 559s 17s/step - loss: 0.7008 - auc: 0.9115 - val_loss: 1.1596 - val_auc: 0.8159
# Epoch 4/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6566 - auc: 0.9210
# Epoch 4: val_auc did not improve from 0.83385
# 33/33 [==============================] - 565s 17s/step - loss: 0.6566 - auc: 0.9210 - val_loss: 1.3551 - val_auc: 0.8055
# Epoch 5/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6652 - auc: 0.9208
# Epoch 5: val_auc did not improve from 0.83385
# 33/33 [==============================] - 560s 17s/step - loss: 0.6652 - auc: 0.9208 - val_loss: 1.3712 - val_auc: 0.7933
# Epoch 6/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6298 - auc: 0.9273
# Epoch 6: val_auc did not improve from 0.83385
# 33/33 [==============================] - 558s 17s/step - loss: 0.6298 - auc: 0.9273 - val_loss: 1.1264 - val_auc: 0.8168
# Epoch 7/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6348 - auc: 0.9267
# Epoch 7: val_auc did not improve from 0.83385
# 33/33 [==============================] - 561s 17s/step - loss: 0.6348 - auc: 0.9267 - val_loss: 1.2466 - val_auc: 0.8131
# Epoch 8/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6311 - auc: 0.9276
# Epoch 8: val_auc did not improve from 0.83385
# 33/33 [==============================] - 590s 18s/step - loss: 0.6311 - auc: 0.9276 - val_loss: 1.2517 - val_auc: 0.8239
# Epoch 9/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6133 - auc: 0.9319
# Epoch 9: val_auc did not improve from 0.83385
# 33/33 [==============================] - 1297s 40s/step - loss: 0.6133 - auc: 0.9319 - val_loss: 1.1441 - val_auc: 0.8274
# Epoch 10/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5956 - auc: 0.9351
# Epoch 10: val_auc improved from 0.83385 to 0.84445, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 568s 17s/step - loss: 0.5956 - auc: 0.9351 - val_loss: 1.0998 - val_auc: 0.8444
# Epoch 11/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5834 - auc: 0.9371
# Epoch 11: val_auc did not improve from 0.84445
# 33/33 [==============================] - 546s 17s/step - loss: 0.5834 - auc: 0.9371 - val_loss: 1.1595 - val_auc: 0.8289
# Epoch 12/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5918 - auc: 0.9362
# Epoch 12: val_auc improved from 0.84445 to 0.85075, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 551s 17s/step - loss: 0.5918 - auc: 0.9362 - val_loss: 1.0482 - val_auc: 0.8508
# Epoch 13/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5854 - auc: 0.9377
# Epoch 13: val_auc improved from 0.85075 to 0.85375, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 559s 17s/step - loss: 0.5854 - auc: 0.9377 - val_loss: 1.1067 - val_auc: 0.8538
# Epoch 14/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5524 - auc: 0.9444
# Epoch 14: val_auc did not improve from 0.85375
# 33/33 [==============================] - 545s 17s/step - loss: 0.5524 - auc: 0.9444 - val_loss: 1.1618 - val_auc: 0.8369
# Epoch 15/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5800 - auc: 0.9387
# Epoch 15: val_auc did not improve from 0.85375
# 33/33 [==============================] - 533s 16s/step - loss: 0.5800 - auc: 0.9387 - val_loss: 1.1383 - val_auc: 0.8309
# Epoch 16/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5564 - auc: 0.9436
# Epoch 16: val_auc did not improve from 0.85375
# 33/33 [==============================] - 539s 16s/step - loss: 0.5564 - auc: 0.9436 - val_loss: 1.0915 - val_auc: 0.8502
# Epoch 17/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5532 - auc: 0.9437
# Epoch 17: val_auc improved from 0.85375 to 0.86306, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 537s 17s/step - loss: 0.5532 - auc: 0.9437 - val_loss: 0.9855 - val_auc: 0.8631
# Epoch 18/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5368 - auc: 0.9470
# Epoch 18: val_auc did not improve from 0.86306
# 33/33 [==============================] - 540s 16s/step - loss: 0.5368 - auc: 0.9470 - val_loss: 1.1460 - val_auc: 0.8488
# Epoch 19/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5396 - auc: 0.9473
# Epoch 19: val_auc did not improve from 0.86306
# 33/33 [==============================] - 540s 16s/step - loss: 0.5396 - auc: 0.9473 - val_loss: 1.0611 - val_auc: 0.8509
# Epoch 20/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5378 - auc: 0.9474
# Epoch 20: val_auc did not improve from 0.86306
# 33/33 [==============================] - 533s 16s/step - loss: 0.5378 - auc: 0.9474 - val_loss: 1.0856 - val_auc: 0.8560
# Epoch 21/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5224 - auc: 0.9498
# Epoch 21: val_auc did not improve from 0.86306
# 33/33 [==============================] - 530s 16s/step - loss: 0.5224 - auc: 0.9498 - val_loss: 1.1685 - val_auc: 0.8483
# Epoch 22/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5160 - auc: 0.9513
# Epoch 22: val_auc did not improve from 0.86306
# 33/33 [==============================] - 533s 16s/step - loss: 0.5160 - auc: 0.9513 - val_loss: 1.2153 - val_auc: 0.8424
# Epoch 23/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5121 - auc: 0.9520
# Epoch 23: val_auc did not improve from 0.86306
# 33/33 [==============================] - 536s 16s/step - loss: 0.5121 - auc: 0.9520 - val_loss: 1.3100 - val_auc: 0.8240
# Epoch 24/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5257 - auc: 0.9499
# Epoch 24: val_auc did not improve from 0.86306
# 33/33 [==============================] - 556s 17s/step - loss: 0.5257 - auc: 0.9499 - val_loss: 1.1001 - val_auc: 0.8464
# Epoch 25/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5373 - auc: 0.9465
# Epoch 25: val_auc did not improve from 0.86306
# 33/33 [==============================] - 650s 19s/step - loss: 0.5373 - auc: 0.9465 - val_loss: 1.1194 - val_auc: 0.8513
# Epoch 26/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5065 - auc: 0.9530
# Epoch 26: val_auc did not improve from 0.86306
# 33/33 [==============================] - 579s 18s/step - loss: 0.5065 - auc: 0.9530 - val_loss: 1.1990 - val_auc: 0.8413
# Epoch 27/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5022 - auc: 0.9540
# Epoch 27: val_auc did not improve from 0.86306
# 33/33 [==============================] - 610s 19s/step - loss: 0.5022 - auc: 0.9540 - val_loss: 1.1444 - val_auc: 0.8517
# Epoch 28/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4948 - auc: 0.9550
# Epoch 28: val_auc did not improve from 0.86306
# 33/33 [==============================] - 564s 17s/step - loss: 0.4948 - auc: 0.9550 - val_loss: 1.0960 - val_auc: 0.8623
# Epoch 29/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4744 - auc: 0.9587
# Epoch 29: val_auc did not improve from 0.86306
# 33/33 [==============================] - 597s 18s/step - loss: 0.4744 - auc: 0.9587 - val_loss: 1.0906 - val_auc: 0.8613
# Epoch 30/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4760 - auc: 0.9582
# Epoch 30: val_auc did not improve from 0.86306
# 33/33 [==============================] - 550s 17s/step - loss: 0.4760 - auc: 0.9582 - val_loss: 1.2278 - val_auc: 0.8391
# Epoch 31/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4834 - auc: 0.9570
# Epoch 31: val_auc did not improve from 0.86306
# 33/33 [==============================] - 562s 17s/step - loss: 0.4834 - auc: 0.9570 - val_loss: 1.2772 - val_auc: 0.8436
# Epoch 32/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4807 - auc: 0.9578
# Epoch 32: val_auc improved from 0.86306 to 0.86374, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 563s 17s/step - loss: 0.4807 - auc: 0.9578 - val_loss: 1.1469 - val_auc: 0.8637
# Epoch 33/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4888 - auc: 0.9562
# Epoch 33: val_auc did not improve from 0.86374
# 33/33 [==============================] - 628s 19s/step - loss: 0.4888 - auc: 0.9562 - val_loss: 1.2462 - val_auc: 0.8476
# Epoch 34/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4689 - auc: 0.9594
# Epoch 34: val_auc improved from 0.86374 to 0.86568, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 635s 19s/step - loss: 0.4689 - auc: 0.9594 - val_loss: 1.0760 - val_auc: 0.8657
# Epoch 35/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4625 - auc: 0.9603
# Epoch 35: val_auc did not improve from 0.86568
# 33/33 [==============================] - 729s 22s/step - loss: 0.4625 - auc: 0.9603 - val_loss: 1.1706 - val_auc: 0.8512
# Epoch 36/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4914 - auc: 0.9553
# Epoch 36: val_auc did not improve from 0.86568
# 33/33 [==============================] - 575s 17s/step - loss: 0.4914 - auc: 0.9553 - val_loss: 1.3183 - val_auc: 0.8440
# Epoch 37/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4690 - auc: 0.9595
# Epoch 37: val_auc did not improve from 0.86568
# 33/33 [==============================] - 569s 17s/step - loss: 0.4690 - auc: 0.9595 - val_loss: 1.1833 - val_auc: 0.8545
# Epoch 38/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4780 - auc: 0.9583
# Epoch 38: val_auc did not improve from 0.86568
# 33/33 [==============================] - 602s 18s/step - loss: 0.4780 - auc: 0.9583 - val_loss: 1.3320 - val_auc: 0.8421
# Epoch 39/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4463 - auc: 0.9630
# Epoch 39: val_auc did not improve from 0.86568
# 33/33 [==============================] - 573s 17s/step - loss: 0.4463 - auc: 0.9630 - val_loss: 1.0976 - val_auc: 0.8595
# Epoch 40/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4841 - auc: 0.9570
# Epoch 40: val_auc did not improve from 0.86568
# 33/33 [==============================] - 576s 18s/step - loss: 0.4841 - auc: 0.9570 - val_loss: 1.2306 - val_auc: 0.8491
# Epoch 41/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4550 - auc: 0.9616
# Epoch 41: val_auc did not improve from 0.86568
# 33/33 [==============================] - 575s 17s/step - loss: 0.4550 - auc: 0.9616 - val_loss: 1.2114 - val_auc: 0.8532
# Epoch 42/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4519 - auc: 0.9623
# Epoch 42: val_auc did not improve from 0.86568
# 33/33 [==============================] - 582s 18s/step - loss: 0.4519 - auc: 0.9623 - val_loss: 1.2477 - val_auc: 0.8475
# Epoch 43/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4644 - auc: 0.9605
# Epoch 43: val_auc improved from 0.86568 to 0.87273, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 566s 17s/step - loss: 0.4644 - auc: 0.9605 - val_loss: 1.1124 - val_auc: 0.8727
# Epoch 44/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4403 - auc: 0.9642
# Epoch 44: val_auc did not improve from 0.87273
# 33/33 [==============================] - 561s 17s/step - loss: 0.4403 - auc: 0.9642 - val_loss: 1.2185 - val_auc: 0.8520
# Epoch 45/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4446 - auc: 0.9633
# Epoch 45: val_auc did not improve from 0.87273
# 33/33 [==============================] - 561s 17s/step - loss: 0.4446 - auc: 0.9633 - val_loss: 1.1516 - val_auc: 0.8674
# Epoch 46/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4448 - auc: 0.9636
# Epoch 46: val_auc did not improve from 0.87273
# 33/33 [==============================] - 550s 17s/step - loss: 0.4448 - auc: 0.9636 - val_loss: 1.2146 - val_auc: 0.8552
# Epoch 47/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4386 - auc: 0.9648
# Epoch 47: val_auc did not improve from 0.87273
# 33/33 [==============================] - 545s 17s/step - loss: 0.4386 - auc: 0.9648 - val_loss: 1.1875 - val_auc: 0.8617
# Epoch 48/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4154 - auc: 0.9681
# Epoch 48: val_auc did not improve from 0.87273
# 33/33 [==============================] - 539s 16s/step - loss: 0.4154 - auc: 0.9681 - val_loss: 1.3253 - val_auc: 0.8505
# Epoch 49/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4124 - auc: 0.9687
# Epoch 49: val_auc did not improve from 0.87273
# 33/33 [==============================] - 554s 17s/step - loss: 0.4124 - auc: 0.9687 - val_loss: 1.1935 - val_auc: 0.8621
# Epoch 50/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4356 - auc: 0.9654
# Epoch 50: val_auc did not improve from 0.87273
# 33/33 [==============================] - 555s 17s/step - loss: 0.4356 - auc: 0.9654 - val_loss: 1.1278 - val_auc: 0.8693
# Epoch 51/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4291 - auc: 0.9663
# Epoch 51: val_auc improved from 0.87273 to 0.87325, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 561s 17s/step - loss: 0.4291 - auc: 0.9663 - val_loss: 1.0282 - val_auc: 0.8733
# Epoch 52/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4211 - auc: 0.9670
# Epoch 52: val_auc improved from 0.87325 to 0.87498, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 565s 17s/step - loss: 0.4211 - auc: 0.9670 - val_loss: 1.0194 - val_auc: 0.8750
# Epoch 53/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4129 - auc: 0.9682
# Epoch 53: val_auc did not improve from 0.87498
# 33/33 [==============================] - 551s 17s/step - loss: 0.4129 - auc: 0.9682 - val_loss: 1.1593 - val_auc: 0.8502
# Epoch 54/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4095 - auc: 0.9691
# Epoch 54: val_auc improved from 0.87498 to 0.88048, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 540s 16s/step - loss: 0.4095 - auc: 0.9691 - val_loss: 1.0129 - val_auc: 0.8805
# Epoch 55/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4041 - auc: 0.9697
# Epoch 55: val_auc did not improve from 0.88048
# 33/33 [==============================] - 563s 17s/step - loss: 0.4041 - auc: 0.9697 - val_loss: 1.1047 - val_auc: 0.8645
# Epoch 56/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4024 - auc: 0.9700
# Epoch 56: val_auc did not improve from 0.88048
# 33/33 [==============================] - 594s 18s/step - loss: 0.4024 - auc: 0.9700 - val_loss: 1.2710 - val_auc: 0.8644
# Epoch 57/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4149 - auc: 0.9678
# Epoch 57: val_auc did not improve from 0.88048
# 33/33 [==============================] - 574s 17s/step - loss: 0.4149 - auc: 0.9678 - val_loss: 1.1386 - val_auc: 0.8607
# Epoch 58/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4335 - auc: 0.9653
# Epoch 58: val_auc did not improve from 0.88048
# 33/33 [==============================] - 552s 17s/step - loss: 0.4335 - auc: 0.9653 - val_loss: 1.1554 - val_auc: 0.8647
# Epoch 59/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3837 - auc: 0.9726
# Epoch 59: val_auc did not improve from 0.88048
# 33/33 [==============================] - 533s 16s/step - loss: 0.3837 - auc: 0.9726 - val_loss: 1.1250 - val_auc: 0.8654
# Epoch 60/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4105 - auc: 0.9688
# Epoch 60: val_auc did not improve from 0.88048
# 33/33 [==============================] - 545s 17s/step - loss: 0.4105 - auc: 0.9688 - val_loss: 1.2202 - val_auc: 0.8679
# Epoch 61/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3992 - auc: 0.9707
# Epoch 61: val_auc did not improve from 0.88048
# 33/33 [==============================] - 550s 17s/step - loss: 0.3992 - auc: 0.9707 - val_loss: 1.2820 - val_auc: 0.8572
# Epoch 62/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3922 - auc: 0.9709
# Epoch 62: val_auc improved from 0.88048 to 0.88861, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 535s 16s/step - loss: 0.3922 - auc: 0.9709 - val_loss: 0.9835 - val_auc: 0.8886
# Epoch 63/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3812 - auc: 0.9729
# Epoch 63: val_auc did not improve from 0.88861
# 33/33 [==============================] - 530s 16s/step - loss: 0.3812 - auc: 0.9729 - val_loss: 1.0800 - val_auc: 0.8870
# Epoch 64/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4101 - auc: 0.9690
# Epoch 64: val_auc improved from 0.88861 to 0.89205, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 529s 16s/step - loss: 0.4101 - auc: 0.9690 - val_loss: 0.9230 - val_auc: 0.8920
# Epoch 65/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3871 - auc: 0.9720
# Epoch 65: val_auc did not improve from 0.89205
# 33/33 [==============================] - 535s 16s/step - loss: 0.3871 - auc: 0.9720 - val_loss: 0.9719 - val_auc: 0.8893
# Epoch 66/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3903 - auc: 0.9718
# Epoch 66: val_auc did not improve from 0.89205
# 33/33 [==============================] - 525s 16s/step - loss: 0.3903 - auc: 0.9718 - val_loss: 0.9629 - val_auc: 0.8869
# Epoch 67/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4323 - auc: 0.9662
# Epoch 67: val_auc did not improve from 0.89205
# 33/33 [==============================] - 526s 16s/step - loss: 0.4323 - auc: 0.9662 - val_loss: 1.1382 - val_auc: 0.8742
# Epoch 68/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3750 - auc: 0.9738
# Epoch 68: val_auc did not improve from 0.89205
# 33/33 [==============================] - 530s 16s/step - loss: 0.3750 - auc: 0.9738 - val_loss: 0.9974 - val_auc: 0.8902
# Epoch 69/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3702 - auc: 0.9745
# Epoch 69: val_auc did not improve from 0.89205
# 33/33 [==============================] - 533s 16s/step - loss: 0.3702 - auc: 0.9745 - val_loss: 1.1274 - val_auc: 0.8732
# Epoch 70/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3739 - auc: 0.9738
# Epoch 70: val_auc did not improve from 0.89205
# 33/33 [==============================] - 524s 16s/step - loss: 0.3739 - auc: 0.9738 - val_loss: 1.1287 - val_auc: 0.8735
# Epoch 71/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3921 - auc: 0.9713
# Epoch 71: val_auc did not improve from 0.89205
# 33/33 [==============================] - 527s 16s/step - loss: 0.3921 - auc: 0.9713 - val_loss: 1.2445 - val_auc: 0.8630
# Epoch 72/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3879 - auc: 0.9723
# Epoch 72: val_auc improved from 0.89205 to 0.89657, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 527s 16s/step - loss: 0.3879 - auc: 0.9723 - val_loss: 0.9303 - val_auc: 0.8966
# Epoch 73/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3528 - auc: 0.9765
# Epoch 73: val_auc did not improve from 0.89657
# 33/33 [==============================] - 527s 16s/step - loss: 0.3528 - auc: 0.9765 - val_loss: 1.1600 - val_auc: 0.8717
# Epoch 74/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3776 - auc: 0.9735
# Epoch 74: val_auc did not improve from 0.89657
# 33/33 [==============================] - 522s 16s/step - loss: 0.3776 - auc: 0.9735 - val_loss: 1.2467 - val_auc: 0.8665
# Epoch 75/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3503 - auc: 0.9770
# Epoch 75: val_auc did not improve from 0.89657
# 33/33 [==============================] - 529s 16s/step - loss: 0.3503 - auc: 0.9770 - val_loss: 1.0216 - val_auc: 0.8880
# Epoch 76/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3619 - auc: 0.9754
# Epoch 76: val_auc did not improve from 0.89657
# 33/33 [==============================] - 524s 16s/step - loss: 0.3619 - auc: 0.9754 - val_loss: 0.9126 - val_auc: 0.8917
# Epoch 77/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3492 - auc: 0.9772
# Epoch 77: val_auc did not improve from 0.89657
# 33/33 [==============================] - 525s 16s/step - loss: 0.3492 - auc: 0.9772 - val_loss: 1.0266 - val_auc: 0.8920
# Epoch 78/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3742 - auc: 0.9737
# Epoch 78: val_auc did not improve from 0.89657
# 33/33 [==============================] - 558s 17s/step - loss: 0.3742 - auc: 0.9737 - val_loss: 1.0203 - val_auc: 0.8865
# Epoch 79/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3598 - auc: 0.9756
# Epoch 79: val_auc did not improve from 0.89657
# 33/33 [==============================] - 555s 17s/step - loss: 0.3598 - auc: 0.9756 - val_loss: 0.9617 - val_auc: 0.8895
# Epoch 80/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3425 - auc: 0.9781
# Epoch 80: val_auc did not improve from 0.89657
# 33/33 [==============================] - 556s 17s/step - loss: 0.3425 - auc: 0.9781 - val_loss: 1.0688 - val_auc: 0.8726
# Epoch 81/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3681 - auc: 0.9747
# Epoch 81: val_auc did not improve from 0.89657
# 33/33 [==============================] - 559s 17s/step - loss: 0.3681 - auc: 0.9747 - val_loss: 1.1751 - val_auc: 0.8644
# Epoch 82/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3452 - auc: 0.9776
# Epoch 82: val_auc did not improve from 0.89657
# 33/33 [==============================] - 557s 17s/step - loss: 0.3452 - auc: 0.9776 - val_loss: 0.9978 - val_auc: 0.8888
# Epoch 83/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3372 - auc: 0.9787
# Epoch 83: val_auc did not improve from 0.89657
# 33/33 [==============================] - 559s 17s/step - loss: 0.3372 - auc: 0.9787 - val_loss: 0.9956 - val_auc: 0.8874
# Epoch 84/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3652 - auc: 0.9752
# Epoch 84: val_auc improved from 0.89657 to 0.90673, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 560s 17s/step - loss: 0.3652 - auc: 0.9752 - val_loss: 0.8494 - val_auc: 0.9067
# Epoch 85/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3477 - auc: 0.9771
# Epoch 85: val_auc did not improve from 0.90673
# 33/33 [==============================] - 559s 17s/step - loss: 0.3477 - auc: 0.9771 - val_loss: 1.0687 - val_auc: 0.8834
# Epoch 86/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3397 - auc: 0.9783
# Epoch 86: val_auc did not improve from 0.90673
# 33/33 [==============================] - 555s 17s/step - loss: 0.3397 - auc: 0.9783 - val_loss: 0.9808 - val_auc: 0.8900
# Epoch 87/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3209 - auc: 0.9804
# Epoch 87: val_auc did not improve from 0.90673
# 33/33 [==============================] - 556s 17s/step - loss: 0.3209 - auc: 0.9804 - val_loss: 0.9545 - val_auc: 0.8959
# Epoch 88/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3533 - auc: 0.9764
# Epoch 88: val_auc did not improve from 0.90673
# 33/33 [==============================] - 560s 17s/step - loss: 0.3533 - auc: 0.9764 - val_loss: 0.9612 - val_auc: 0.8925
# Epoch 89/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3601 - auc: 0.9761
# Epoch 89: val_auc did not improve from 0.90673
# 33/33 [==============================] - 24551s 767s/step - loss: 0.3601 - auc: 0.9761 - val_loss: 1.0069 - val_auc: 0.8884
# Epoch 90/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3283 - auc: 0.9797
# Epoch 90: val_auc did not improve from 0.90673
# 33/33 [==============================] - 564s 17s/step - loss: 0.3283 - auc: 0.9797 - val_loss: 0.9543 - val_auc: 0.8957
# Epoch 91/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3083 - auc: 0.9821
# Epoch 91: val_auc did not improve from 0.90673
# 33/33 [==============================] - 537s 16s/step - loss: 0.3083 - auc: 0.9821 - val_loss: 1.0645 - val_auc: 0.8774
# Epoch 92/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3367 - auc: 0.9787
# Epoch 92: val_auc did not improve from 0.90673
# 33/33 [==============================] - 540s 16s/step - loss: 0.3367 - auc: 0.9787 - val_loss: 0.9362 - val_auc: 0.8966
# Epoch 93/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3127 - auc: 0.9817
# Epoch 93: val_auc improved from 0.90673 to 0.90934, saving model to .\best_weights.hdf5
# 33/33 [==============================] - 541s 16s/step - loss: 0.3127 - auc: 0.9817 - val_loss: 0.8343 - val_auc: 0.9093
# Epoch 94/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3221 - auc: 0.9802
# Epoch 94: val_auc did not improve from 0.90934
# 33/33 [==============================] - 551s 17s/step - loss: 0.3221 - auc: 0.9802 - val_loss: 1.0598 - val_auc: 0.8850
# Epoch 95/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3050 - auc: 0.9824
# Epoch 95: val_auc did not improve from 0.90934
# 33/33 [==============================] - 542s 16s/step - loss: 0.3050 - auc: 0.9824 - val_loss: 1.0384 - val_auc: 0.8918
# Epoch 96/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3182 - auc: 0.9806
# Epoch 96: val_auc did not improve from 0.90934
# 33/33 [==============================] - 538s 16s/step - loss: 0.3182 - auc: 0.9806 - val_loss: 1.2546 - val_auc: 0.8680
# Epoch 97/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3205 - auc: 0.9805
# Epoch 97: val_auc did not improve from 0.90934
# 33/33 [==============================] - 537s 16s/step - loss: 0.3205 - auc: 0.9805 - val_loss: 1.1819 - val_auc: 0.8725
# Epoch 98/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3031 - auc: 0.9824
# Epoch 98: val_auc did not improve from 0.90934
# 33/33 [==============================] - 535s 16s/step - loss: 0.3031 - auc: 0.9824 - val_loss: 1.0462 - val_auc: 0.8867
# Epoch 99/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3171 - auc: 0.9813
# Epoch 99: val_auc did not improve from 0.90934
# 33/33 [==============================] - 552s 17s/step - loss: 0.3171 - auc: 0.9813 - val_loss: 1.0272 - val_auc: 0.8966
# Epoch 100/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3281 - auc: 0.9795
# Epoch 100: val_auc did not improve from 0.90934
# 33/33 [==============================] - 545s 17s/step - loss: 0.3281 - auc: 0.9795 - val_loss: 1.1155 - val_auc: 0.8821
# Epoch 101/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3202 - auc: 0.9800
# Epoch 101: val_auc did not improve from 0.90934
# 33/33 [==============================] - 540s 16s/step - loss: 0.3202 - auc: 0.9800 - val_loss: 0.9542 - val_auc: 0.9031
# Epoch 102/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3093 - auc: 0.9819
# Epoch 102: val_auc did not improve from 0.90934
# 33/33 [==============================] - 543s 17s/step - loss: 0.3093 - auc: 0.9819 - val_loss: 1.0849 - val_auc: 0.8826
# Epoch 103/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3092 - auc: 0.9816
# Epoch 103: val_auc did not improve from 0.90934
# 33/33 [==============================] - 539s 16s/step - loss: 0.3092 - auc: 0.9816 - val_loss: 1.0677 - val_auc: 0.8904
# Epoch 104/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3221 - auc: 0.9803
# Epoch 104: val_auc did not improve from 0.90934
# 33/33 [==============================] - 608s 19s/step - loss: 0.3221 - auc: 0.9803 - val_loss: 1.0575 - val_auc: 0.8835
# Epoch 105/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3247 - auc: 0.9805
# Epoch 105: val_auc did not improve from 0.90934
# 33/33 [==============================] - 544s 17s/step - loss: 0.3247 - auc: 0.9805 - val_loss: 1.0846 - val_auc: 0.8834
# Epoch 106/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3156 - auc: 0.9811
# Epoch 106: val_auc did not improve from 0.90934
# 33/33 [==============================] - 551s 17s/step - loss: 0.3156 - auc: 0.9811 - val_loss: 1.1131 - val_auc: 0.8840
# Epoch 107/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3048 - auc: 0.9824
# Epoch 107: val_auc did not improve from 0.90934
# 33/33 [==============================] - 551s 17s/step - loss: 0.3048 - auc: 0.9824 - val_loss: 0.9581 - val_auc: 0.8901
# Epoch 108/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3084 - auc: 0.9820
# Epoch 108: val_auc did not improve from 0.90934
# 33/33 [==============================] - 545s 17s/step - loss: 0.3084 - auc: 0.9820 - val_loss: 1.0427 - val_auc: 0.8912
# Epoch 108: early stopping

# %% [markdown]
# ### MODEL EVALUATION

# %%
# Summarize history for loss

plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Summarize history for loss

plt.plot(model_history.history['auc'])
plt.plot(model_history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Test Data 

test_dataset  = test_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test',
                                                 target_size = (224,224),
                                                 class_mode = 'categorical',
                                                 batch_size = 128)
# Out:
# Found 1279 images belonging to 4 classes.

# %%
# Evaluating Loss and AUC

model.evaluate(test_dataset)
# Out:
# 10/10 [==============================] - 110s 11s/step - loss: 1.1051 - auc: 0.8970
# [1.1051173210144043, 0.8969542384147644]

# %%
# Test Case 1: Non-Dementia

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/NonDemented/26 (100).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = model.predict(img)
classes_x=np.argmax(answer,axis=1)

def predict_prob(number):
  return [number[0],1-number[0]]

y_prob = np.array(list(map(predict_prob, model.predict(img))))

probability = round(np.max(y_prob*100),2)

print(probability,'% chances are there that the image is',idc[classes_x[0]])
# Out:
# 100.0 % chances are there that the image is NonDemented

# %%
# Test Case 2: Mild Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/MildDemented/27 (19).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = model.predict(img)
classes_x=np.argmax(answer,axis=1)

def predict_prob(number):
  return [number[0],1-number[0]]

y_prob = np.array(list(map(predict_prob, model.predict(img))))

probability = round(np.max(y_prob*100),2)

print(probability,'% chances are there that the image is',idc[classes_x[0]])
# Out:
# 81.33 % chances are there that the image is MildDemented

# %%
# Test Case 3: Moderate Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/ModerateDemented/27 (2).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = model.predict(img)
classes_x=np.argmax(answer,axis=1)

def predict_prob(number):
  return [number[0],1-number[0]]

y_prob = np.array(list(map(predict_prob, model.predict(img))))

probability = round(np.max(y_prob*100),2)

print(probability,'% chances are there that the image is',idc[classes_x[0]])
# Out:
# 95.2 % chances are there that the image is ModerateDemented

# %%
# Test Case 4: Very Mild Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/VeryMildDemented/27 (67).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = model.predict(img)
classes_x=np.argmax(answer,axis=1)

def predict_prob(number):
  return [number[0],1-number[0]]

y_prob = np.array(list(map(predict_prob, model.predict(img))))

probability = round(np.max(y_prob*100),2)

print(probability,'% chances are there that the image is',idc[classes_x[0]])
# Out:
# 99.82 % chances are there that the image is VeryMildDemented

# %% [markdown]
# Conclusion:
#
# So, we have finally built are deep learning model using DenseNet162 transfer learning algorithm and acheived and AUC-90%.
