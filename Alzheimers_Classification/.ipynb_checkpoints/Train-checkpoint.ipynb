# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io
import os 
import tqdm
import glob
import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from skimage.io import imshow
from skimage.transform import resize
from skimage.color import gray2rgb

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.densenet import DenseNet169

# %% [markdown]
# ### IMPORT / VIEWING / PREPROCESSING DATASET

# %%
#Data Augmentation

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=30,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   validation_split = 0.2)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '../Alzheimer_s Dataset/train',
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 40,
                                                   shuffle=True)
# Out:
# Found 4098 images belonging to 4 classes.

# %%
valid_dataset = train_datagen.flow_from_directory(directory = '../Alzheimer_s Dataset/train',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 40,
                                                  shuffle=True)
# Out:
# Found 1023 images belonging to 4 classes.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 10, figsize=(20,20))

for i in range(0,10):
    rand1 = np.random.randint(len(train_dataset))
    rand2 = np.random.randint(40)
    ax[i].imshow(train_dataset[rand1][0][rand2])
    ax[i].axis('off')
    a = train_dataset[rand1][1][rand2]
    if a[0] == 1:
        ax[i].set_title('Mild Dementia')
    elif a[1] == 1:
        ax[i].set_title('Moderate Dementia')
    elif a[2] == 1:
        ax[i].set_title('Non Demetia')
    elif a[3] == 1:
        ax[i].set_title('Very Mild Dementia')

# %% [markdown]
# ### MODEL BUILDING

# %%
# Model Initialization

base_model = DenseNet169(input_shape=(224,224,3), 
                         include_top=False,
                         weights="imagenet")

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(2048,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4,activation='softmax'))

# %%
# Summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 7, 7, 1664)        12642880
#
#  dropout (Dropout)           (None, 7, 7, 1664)        0
#
#  flatten (Flatten)           (None, 81536)             0
#
#  batch_normalization (BatchN  (None, 81536)            326144
#  ormalization)
#
#  dense (Dense)               (None, 2048)              166987776
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  activation (Activation)     (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  activation_1 (Activation)   (None, 1024)              0
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 182,071,364
# Trainable params: 169,259,268
# Non-trainable params: 12,812,096
# _________________________________________________________________

# %%
# Model Compile 

OPT    = tensorflow.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='categorical_crossentropy',
              metrics=[tensorflow.keras.metrics.AUC(name = 'auc')],
              optimizer=OPT)

# %%
# Defining Callbacks

filepath = './best_weights.hdf5'

earlystopping = EarlyStopping(monitor = 'val_auc', 
                              mode = 'max' , 
                              patience = 10,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'val_auc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)


callback_list = [earlystopping, checkpoint]

# %%
model_history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 100,
                        steps_per_epoch=100,
                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - ETA: 0s - loss: 1.3677 - auc: 0.7881
# Epoch 1: val_auc improved from -inf to 0.69321, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 733s 7s/step - loss: 1.3677 - auc: 0.7881 - val_loss: 1.8889 - val_auc: 0.6932
# Epoch 2/100
# 100/100 [==============================] - ETA: 0s - loss: 1.0097 - auc: 0.8421
# Epoch 2: val_auc improved from 0.69321 to 0.75632, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 691s 7s/step - loss: 1.0097 - auc: 0.8421 - val_loss: 1.3425 - val_auc: 0.7563
# Epoch 3/100
# 100/100 [==============================] - ETA: 0s - loss: 0.9555 - auc: 0.8504
# Epoch 3: val_auc improved from 0.75632 to 0.76969, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 689s 7s/step - loss: 0.9555 - auc: 0.8504 - val_loss: 1.1809 - val_auc: 0.7697
# Epoch 4/100
# 100/100 [==============================] - ETA: 0s - loss: 0.8804 - auc: 0.8648
# Epoch 4: val_auc did not improve from 0.76969
# 100/100 [==============================] - 671s 7s/step - loss: 0.8804 - auc: 0.8648 - val_loss: 1.2433 - val_auc: 0.7537
# Epoch 5/100
# 100/100 [==============================] - ETA: 0s - loss: 0.8259 - auc: 0.8785
# Epoch 5: val_auc improved from 0.76969 to 0.77540, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 673s 7s/step - loss: 0.8259 - auc: 0.8785 - val_loss: 1.1648 - val_auc: 0.7754
# Epoch 6/100
# 100/100 [==============================] - ETA: 0s - loss: 0.8042 - auc: 0.8852
# Epoch 6: val_auc improved from 0.77540 to 0.78304, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 677s 7s/step - loss: 0.8042 - auc: 0.8852 - val_loss: 1.1568 - val_auc: 0.7830
# Epoch 7/100
# 100/100 [==============================] - ETA: 0s - loss: 0.7768 - auc: 0.8911
# Epoch 7: val_auc improved from 0.78304 to 0.79130, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 677s 7s/step - loss: 0.7768 - auc: 0.8911 - val_loss: 1.1245 - val_auc: 0.7913
# Epoch 8/100
# 100/100 [==============================] - ETA: 0s - loss: 0.7384 - auc: 0.8988
# Epoch 8: val_auc did not improve from 0.79130
# 100/100 [==============================] - 670s 7s/step - loss: 0.7384 - auc: 0.8988 - val_loss: 1.2603 - val_auc: 0.7685
# Epoch 9/100
# 100/100 [==============================] - ETA: 0s - loss: 0.7270 - auc: 0.9033
# Epoch 9: val_auc improved from 0.79130 to 0.80578, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 668s 7s/step - loss: 0.7270 - auc: 0.9033 - val_loss: 1.1146 - val_auc: 0.8058
# Epoch 10/100
# 100/100 [==============================] - ETA: 0s - loss: 0.7204 - auc: 0.9047
# Epoch 10: val_auc did not improve from 0.80578
# 100/100 [==============================] - 675s 7s/step - loss: 0.7204 - auc: 0.9047 - val_loss: 1.1227 - val_auc: 0.7984
# Epoch 11/100
# 100/100 [==============================] - ETA: 0s - loss: 0.7096 - auc: 0.9080
# Epoch 11: val_auc did not improve from 0.80578
# 100/100 [==============================] - 685s 7s/step - loss: 0.7096 - auc: 0.9080 - val_loss: 1.1593 - val_auc: 0.7931
# Epoch 12/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6878 - auc: 0.9128
# Epoch 12: val_auc did not improve from 0.80578
# 100/100 [==============================] - 672s 7s/step - loss: 0.6878 - auc: 0.9128 - val_loss: 1.2033 - val_auc: 0.7856
# Epoch 13/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6914 - auc: 0.9128
# Epoch 13: val_auc did not improve from 0.80578
# 100/100 [==============================] - 665s 7s/step - loss: 0.6914 - auc: 0.9128 - val_loss: 1.2614 - val_auc: 0.7928
# Epoch 14/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6689 - auc: 0.9186
# Epoch 14: val_auc improved from 0.80578 to 0.80750, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 661s 7s/step - loss: 0.6689 - auc: 0.9186 - val_loss: 1.1173 - val_auc: 0.8075
# Epoch 15/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6603 - auc: 0.9203
# Epoch 15: val_auc did not improve from 0.80750
# 100/100 [==============================] - 664s 7s/step - loss: 0.6603 - auc: 0.9203 - val_loss: 1.1035 - val_auc: 0.8047
# Epoch 16/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6553 - auc: 0.9210
# Epoch 16: val_auc improved from 0.80750 to 0.81310, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 675s 7s/step - loss: 0.6553 - auc: 0.9210 - val_loss: 1.0939 - val_auc: 0.8131
# Epoch 17/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6362 - auc: 0.9252
# Epoch 17: val_auc improved from 0.81310 to 0.82687, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 676s 7s/step - loss: 0.6362 - auc: 0.9252 - val_loss: 1.0718 - val_auc: 0.8269
# Epoch 18/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6337 - auc: 0.9272
# Epoch 18: val_auc did not improve from 0.82687
# 100/100 [==============================] - 661s 7s/step - loss: 0.6337 - auc: 0.9272 - val_loss: 1.1987 - val_auc: 0.7977
# Epoch 19/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6376 - auc: 0.9246
# Epoch 19: val_auc improved from 0.82687 to 0.83035, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 669s 7s/step - loss: 0.6376 - auc: 0.9246 - val_loss: 1.0625 - val_auc: 0.8303
# Epoch 20/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6257 - auc: 0.9281
# Epoch 20: val_auc did not improve from 0.83035
# 100/100 [==============================] - 658s 7s/step - loss: 0.6257 - auc: 0.9281 - val_loss: 1.0745 - val_auc: 0.8245
# Epoch 21/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6077 - auc: 0.9323
# Epoch 21: val_auc did not improve from 0.83035
# 100/100 [==============================] - 663s 7s/step - loss: 0.6077 - auc: 0.9323 - val_loss: 1.2029 - val_auc: 0.8003
# Epoch 22/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6141 - auc: 0.9302
# Epoch 22: val_auc improved from 0.83035 to 0.83615, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 673s 7s/step - loss: 0.6141 - auc: 0.9302 - val_loss: 1.0429 - val_auc: 0.8362
# Epoch 23/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5824 - auc: 0.9372
# Epoch 23: val_auc did not improve from 0.83615
# 100/100 [==============================] - 735s 7s/step - loss: 0.5824 - auc: 0.9372 - val_loss: 1.0891 - val_auc: 0.8276
# Epoch 24/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5814 - auc: 0.9378
# Epoch 24: val_auc did not improve from 0.83615
# 100/100 [==============================] - 714s 7s/step - loss: 0.5814 - auc: 0.9378 - val_loss: 1.0527 - val_auc: 0.8338
# Epoch 25/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5798 - auc: 0.9383
# Epoch 25: val_auc improved from 0.83615 to 0.83674, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 671s 7s/step - loss: 0.5798 - auc: 0.9383 - val_loss: 1.0926 - val_auc: 0.8367
# Epoch 26/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5784 - auc: 0.9386
# Epoch 26: val_auc did not improve from 0.83674
# 100/100 [==============================] - 764s 8s/step - loss: 0.5784 - auc: 0.9386 - val_loss: 1.0866 - val_auc: 0.8230
# Epoch 27/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5732 - auc: 0.9392
# Epoch 27: val_auc did not improve from 0.83674
# 100/100 [==============================] - 750s 8s/step - loss: 0.5732 - auc: 0.9392 - val_loss: 1.0488 - val_auc: 0.8365
# Epoch 28/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5644 - auc: 0.9421
# Epoch 28: val_auc improved from 0.83674 to 0.85509, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 675s 7s/step - loss: 0.5644 - auc: 0.9421 - val_loss: 0.9692 - val_auc: 0.8551
# Epoch 29/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5543 - auc: 0.9433
# Epoch 29: val_auc did not improve from 0.85509
# 100/100 [==============================] - 684s 7s/step - loss: 0.5543 - auc: 0.9433 - val_loss: 1.0749 - val_auc: 0.8365
# Epoch 30/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5696 - auc: 0.9407
# Epoch 30: val_auc did not improve from 0.85509
# 100/100 [==============================] - 667s 7s/step - loss: 0.5696 - auc: 0.9407 - val_loss: 1.0505 - val_auc: 0.8394
# Epoch 31/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5317 - auc: 0.9479
# Epoch 31: val_auc improved from 0.85509 to 0.85802, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 672s 7s/step - loss: 0.5317 - auc: 0.9479 - val_loss: 0.9664 - val_auc: 0.8580
# Epoch 32/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5640 - auc: 0.9417
# Epoch 32: val_auc did not improve from 0.85802
# 100/100 [==============================] - 691s 7s/step - loss: 0.5640 - auc: 0.9417 - val_loss: 0.9755 - val_auc: 0.8485
# Epoch 33/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5455 - auc: 0.9458
# Epoch 33: val_auc did not improve from 0.85802
# 100/100 [==============================] - 672s 7s/step - loss: 0.5455 - auc: 0.9458 - val_loss: 1.0985 - val_auc: 0.8345
# Epoch 34/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5285 - auc: 0.9486
# Epoch 34: val_auc did not improve from 0.85802
# 100/100 [==============================] - 675s 7s/step - loss: 0.5285 - auc: 0.9486 - val_loss: 1.0298 - val_auc: 0.8414
# Epoch 35/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5297 - auc: 0.9485
# Epoch 35: val_auc did not improve from 0.85802
# 100/100 [==============================] - 668s 7s/step - loss: 0.5297 - auc: 0.9485 - val_loss: 0.9839 - val_auc: 0.8576
# Epoch 36/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5143 - auc: 0.9513
# Epoch 36: val_auc improved from 0.85802 to 0.86222, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 669s 7s/step - loss: 0.5143 - auc: 0.9513 - val_loss: 0.9548 - val_auc: 0.8622
# Epoch 37/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5092 - auc: 0.9523
# Epoch 37: val_auc did not improve from 0.86222
# 100/100 [==============================] - 674s 7s/step - loss: 0.5092 - auc: 0.9523 - val_loss: 0.9995 - val_auc: 0.8521
# Epoch 38/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5058 - auc: 0.9529
# Epoch 38: val_auc did not improve from 0.86222
# 100/100 [==============================] - 673s 7s/step - loss: 0.5058 - auc: 0.9529 - val_loss: 1.0521 - val_auc: 0.8443
# Epoch 39/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5057 - auc: 0.9534
# Epoch 39: val_auc did not improve from 0.86222
# 100/100 [==============================] - 667s 7s/step - loss: 0.5057 - auc: 0.9534 - val_loss: 0.9573 - val_auc: 0.8618
# Epoch 40/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5191 - auc: 0.9506
# Epoch 40: val_auc did not improve from 0.86222
# 100/100 [==============================] - 665s 7s/step - loss: 0.5191 - auc: 0.9506 - val_loss: 0.9600 - val_auc: 0.8588
# Epoch 41/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4768 - auc: 0.9578
# Epoch 41: val_auc improved from 0.86222 to 0.86561, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 665s 7s/step - loss: 0.4768 - auc: 0.9578 - val_loss: 0.9386 - val_auc: 0.8656
# Epoch 42/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4887 - auc: 0.9559
# Epoch 42: val_auc did not improve from 0.86561
# 100/100 [==============================] - 677s 7s/step - loss: 0.4887 - auc: 0.9559 - val_loss: 0.9772 - val_auc: 0.8569
# Epoch 43/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4775 - auc: 0.9580
# Epoch 43: val_auc improved from 0.86561 to 0.86791, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 669s 7s/step - loss: 0.4775 - auc: 0.9580 - val_loss: 0.9436 - val_auc: 0.8679
# Epoch 44/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4767 - auc: 0.9578
# Epoch 44: val_auc did not improve from 0.86791
# 100/100 [==============================] - 669s 7s/step - loss: 0.4767 - auc: 0.9578 - val_loss: 1.0423 - val_auc: 0.8546
# Epoch 45/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4929 - auc: 0.9555
# Epoch 45: val_auc did not improve from 0.86791
# 100/100 [==============================] - 671s 7s/step - loss: 0.4929 - auc: 0.9555 - val_loss: 0.9625 - val_auc: 0.8627
# Epoch 46/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4766 - auc: 0.9578
# Epoch 46: val_auc did not improve from 0.86791
# 100/100 [==============================] - 666s 7s/step - loss: 0.4766 - auc: 0.9578 - val_loss: 1.0081 - val_auc: 0.8578
# Epoch 47/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4741 - auc: 0.9584
# Epoch 47: val_auc did not improve from 0.86791
# 100/100 [==============================] - 664s 7s/step - loss: 0.4741 - auc: 0.9584 - val_loss: 0.9795 - val_auc: 0.8636
# Epoch 48/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4631 - auc: 0.9601
# Epoch 48: val_auc improved from 0.86791 to 0.87688, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 675s 7s/step - loss: 0.4631 - auc: 0.9601 - val_loss: 0.9248 - val_auc: 0.8769
# Epoch 49/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4436 - auc: 0.9637
# Epoch 49: val_auc did not improve from 0.87688
# 100/100 [==============================] - 666s 7s/step - loss: 0.4436 - auc: 0.9637 - val_loss: 1.0083 - val_auc: 0.8633
# Epoch 50/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4644 - auc: 0.9601
# Epoch 50: val_auc did not improve from 0.87688
# 100/100 [==============================] - 664s 7s/step - loss: 0.4644 - auc: 0.9601 - val_loss: 1.0209 - val_auc: 0.8599
# Epoch 51/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4587 - auc: 0.9609
# Epoch 51: val_auc did not improve from 0.87688
# 100/100 [==============================] - 665s 7s/step - loss: 0.4587 - auc: 0.9609 - val_loss: 1.0596 - val_auc: 0.8579
# Epoch 52/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4742 - auc: 0.9589
# Epoch 52: val_auc did not improve from 0.87688
# 100/100 [==============================] - 665s 7s/step - loss: 0.4742 - auc: 0.9589 - val_loss: 0.9232 - val_auc: 0.8753
# Epoch 53/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4312 - auc: 0.9654
# Epoch 53: val_auc improved from 0.87688 to 0.88399, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 672s 7s/step - loss: 0.4312 - auc: 0.9654 - val_loss: 0.8826 - val_auc: 0.8840
# Epoch 54/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4306 - auc: 0.9658
# Epoch 54: val_auc did not improve from 0.88399
# 100/100 [==============================] - 668s 7s/step - loss: 0.4306 - auc: 0.9658 - val_loss: 0.9468 - val_auc: 0.8755
# Epoch 55/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4338 - auc: 0.9652
# Epoch 55: val_auc did not improve from 0.88399
# 100/100 [==============================] - 669s 7s/step - loss: 0.4338 - auc: 0.9652 - val_loss: 1.0162 - val_auc: 0.8587
# Epoch 56/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4386 - auc: 0.9646
# Epoch 56: val_auc did not improve from 0.88399
# 100/100 [==============================] - 667s 7s/step - loss: 0.4386 - auc: 0.9646 - val_loss: 1.0428 - val_auc: 0.8541
# Epoch 57/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4448 - auc: 0.9634
# Epoch 57: val_auc did not improve from 0.88399
# 100/100 [==============================] - 662s 7s/step - loss: 0.4448 - auc: 0.9634 - val_loss: 0.9237 - val_auc: 0.8826
# Epoch 58/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4178 - auc: 0.9676
# Epoch 58: val_auc did not improve from 0.88399
# 100/100 [==============================] - 662s 7s/step - loss: 0.4178 - auc: 0.9676 - val_loss: 0.9773 - val_auc: 0.8648
# Epoch 59/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4389 - auc: 0.9644
# Epoch 59: val_auc did not improve from 0.88399
# 100/100 [==============================] - 662s 7s/step - loss: 0.4389 - auc: 0.9644 - val_loss: 0.9277 - val_auc: 0.8740
# Epoch 60/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4316 - auc: 0.9655
# Epoch 60: val_auc improved from 0.88399 to 0.88428, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 666s 7s/step - loss: 0.4316 - auc: 0.9655 - val_loss: 0.9156 - val_auc: 0.8843
# Epoch 61/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4212 - auc: 0.9669
# Epoch 61: val_auc did not improve from 0.88428
# 100/100 [==============================] - 668s 7s/step - loss: 0.4212 - auc: 0.9669 - val_loss: 0.9053 - val_auc: 0.8787
# Epoch 62/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4099 - auc: 0.9690
# Epoch 62: val_auc did not improve from 0.88428
# 100/100 [==============================] - 662s 7s/step - loss: 0.4099 - auc: 0.9690 - val_loss: 0.9599 - val_auc: 0.8717
# Epoch 63/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4058 - auc: 0.9693
# Epoch 63: val_auc improved from 0.88428 to 0.89787, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 668s 7s/step - loss: 0.4058 - auc: 0.9693 - val_loss: 0.8358 - val_auc: 0.8979
# Epoch 64/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3965 - auc: 0.9708
# Epoch 64: val_auc did not improve from 0.89787
# 100/100 [==============================] - 673s 7s/step - loss: 0.3965 - auc: 0.9708 - val_loss: 0.8959 - val_auc: 0.8858
# Epoch 65/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4182 - auc: 0.9676
# Epoch 65: val_auc did not improve from 0.89787
# 100/100 [==============================] - 737s 7s/step - loss: 0.4182 - auc: 0.9676 - val_loss: 0.9044 - val_auc: 0.8785
# Epoch 66/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4126 - auc: 0.9683
# Epoch 66: val_auc did not improve from 0.89787
# 100/100 [==============================] - 702s 7s/step - loss: 0.4126 - auc: 0.9683 - val_loss: 0.8770 - val_auc: 0.8868
# Epoch 67/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4071 - auc: 0.9693
# Epoch 67: val_auc did not improve from 0.89787
# 100/100 [==============================] - 673s 7s/step - loss: 0.4071 - auc: 0.9693 - val_loss: 0.9473 - val_auc: 0.8704
# Epoch 68/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3999 - auc: 0.9697
# Epoch 68: val_auc did not improve from 0.89787
# 100/100 [==============================] - 662s 7s/step - loss: 0.3999 - auc: 0.9697 - val_loss: 0.9468 - val_auc: 0.8789
# Epoch 69/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3913 - auc: 0.9717
# Epoch 69: val_auc did not improve from 0.89787
# 100/100 [==============================] - 664s 7s/step - loss: 0.3913 - auc: 0.9717 - val_loss: 0.9310 - val_auc: 0.8782
# Epoch 70/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3977 - auc: 0.9706
# Epoch 70: val_auc did not improve from 0.89787
# 100/100 [==============================] - 676s 7s/step - loss: 0.3977 - auc: 0.9706 - val_loss: 0.9555 - val_auc: 0.8776
# Epoch 71/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3968 - auc: 0.9706
# Epoch 71: val_auc did not improve from 0.89787
# 100/100 [==============================] - 678s 7s/step - loss: 0.3968 - auc: 0.9706 - val_loss: 0.8454 - val_auc: 0.8940
# Epoch 72/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3744 - auc: 0.9735
# Epoch 72: val_auc did not improve from 0.89787
# 100/100 [==============================] - 667s 7s/step - loss: 0.3744 - auc: 0.9735 - val_loss: 0.8651 - val_auc: 0.8915
# Epoch 73/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3531 - auc: 0.9766
# Epoch 73: val_auc improved from 0.89787 to 0.89861, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 672s 7s/step - loss: 0.3531 - auc: 0.9766 - val_loss: 0.8448 - val_auc: 0.8986
# Epoch 74/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3657 - auc: 0.9748
# Epoch 74: val_auc did not improve from 0.89861
# 100/100 [==============================] - 689s 7s/step - loss: 0.3657 - auc: 0.9748 - val_loss: 0.8697 - val_auc: 0.8966
# Epoch 75/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3651 - auc: 0.9753
# Epoch 75: val_auc did not improve from 0.89861
# 100/100 [==============================] - 690s 7s/step - loss: 0.3651 - auc: 0.9753 - val_loss: 0.8868 - val_auc: 0.8887
# Epoch 76/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3715 - auc: 0.9746
# Epoch 76: val_auc did not improve from 0.89861
# 100/100 [==============================] - 699s 7s/step - loss: 0.3715 - auc: 0.9746 - val_loss: 0.8961 - val_auc: 0.8923
# Epoch 77/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3512 - auc: 0.9766
# Epoch 77: val_auc improved from 0.89861 to 0.90357, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 676s 7s/step - loss: 0.3512 - auc: 0.9766 - val_loss: 0.8272 - val_auc: 0.9036
# Epoch 78/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3606 - auc: 0.9758
# Epoch 78: val_auc did not improve from 0.90357
# 100/100 [==============================] - 687s 7s/step - loss: 0.3606 - auc: 0.9758 - val_loss: 0.8744 - val_auc: 0.8952
# Epoch 79/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3637 - auc: 0.9751
# Epoch 79: val_auc did not improve from 0.90357
# 100/100 [==============================] - 669s 7s/step - loss: 0.3637 - auc: 0.9751 - val_loss: 0.8013 - val_auc: 0.9031
# Epoch 80/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3478 - auc: 0.9771
# Epoch 80: val_auc did not improve from 0.90357
# 100/100 [==============================] - 671s 7s/step - loss: 0.3478 - auc: 0.9771 - val_loss: 0.9095 - val_auc: 0.8881
# Epoch 81/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3662 - auc: 0.9746
# Epoch 81: val_auc did not improve from 0.90357
# 100/100 [==============================] - 667s 7s/step - loss: 0.3662 - auc: 0.9746 - val_loss: 0.8746 - val_auc: 0.8937
# Epoch 82/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3665 - auc: 0.9748
# Epoch 82: val_auc did not improve from 0.90357
# 100/100 [==============================] - 669s 7s/step - loss: 0.3665 - auc: 0.9748 - val_loss: 0.8887 - val_auc: 0.8911
# Epoch 83/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3341 - auc: 0.9787
# Epoch 83: val_auc did not improve from 0.90357
# 100/100 [==============================] - 689s 7s/step - loss: 0.3341 - auc: 0.9787 - val_loss: 0.8745 - val_auc: 0.8976
# Epoch 84/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3591 - auc: 0.9758
# Epoch 84: val_auc did not improve from 0.90357
# 100/100 [==============================] - 669s 7s/step - loss: 0.3591 - auc: 0.9758 - val_loss: 0.8670 - val_auc: 0.8965
# Epoch 85/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3433 - auc: 0.9778
# Epoch 85: val_auc improved from 0.90357 to 0.90683, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 675s 7s/step - loss: 0.3433 - auc: 0.9778 - val_loss: 0.8175 - val_auc: 0.9068
# Epoch 86/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3346 - auc: 0.9789
# Epoch 86: val_auc did not improve from 0.90683
# 100/100 [==============================] - 675s 7s/step - loss: 0.3346 - auc: 0.9789 - val_loss: 0.8271 - val_auc: 0.9051
# Epoch 87/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3354 - auc: 0.9787
# Epoch 87: val_auc improved from 0.90683 to 0.91266, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 673s 7s/step - loss: 0.3354 - auc: 0.9787 - val_loss: 0.7640 - val_auc: 0.9127
# Epoch 88/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3157 - auc: 0.9810
# Epoch 88: val_auc did not improve from 0.91266
# 100/100 [==============================] - 671s 7s/step - loss: 0.3157 - auc: 0.9810 - val_loss: 0.8999 - val_auc: 0.8953
# Epoch 89/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3462 - auc: 0.9771
# Epoch 89: val_auc did not improve from 0.91266
# 100/100 [==============================] - 667s 7s/step - loss: 0.3462 - auc: 0.9771 - val_loss: 0.8462 - val_auc: 0.9038
# Epoch 90/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3278 - auc: 0.9797
# Epoch 90: val_auc did not improve from 0.91266
# 100/100 [==============================] - 663s 7s/step - loss: 0.3278 - auc: 0.9797 - val_loss: 0.8559 - val_auc: 0.9020
# Epoch 91/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3328 - auc: 0.9791
# Epoch 91: val_auc improved from 0.91266 to 0.91582, saving model to .\best_weights.hdf5
# 100/100 [==============================] - 671s 7s/step - loss: 0.3328 - auc: 0.9791 - val_loss: 0.7463 - val_auc: 0.9158
# Epoch 92/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3279 - auc: 0.9795
# Epoch 92: val_auc did not improve from 0.91582
# 100/100 [==============================] - 671s 7s/step - loss: 0.3279 - auc: 0.9795 - val_loss: 0.7931 - val_auc: 0.9082
# Epoch 93/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3275 - auc: 0.9797
# Epoch 93: val_auc did not improve from 0.91582
# 100/100 [==============================] - 663s 7s/step - loss: 0.3275 - auc: 0.9797 - val_loss: 0.9093 - val_auc: 0.8938
# Epoch 94/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3254 - auc: 0.9800
# Epoch 94: val_auc did not improve from 0.91582
# 100/100 [==============================] - 666s 7s/step - loss: 0.3254 - auc: 0.9800 - val_loss: 0.8127 - val_auc: 0.9064
# Epoch 95/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3165 - auc: 0.9811
# Epoch 95: val_auc did not improve from 0.91582
# 100/100 [==============================] - 666s 7s/step - loss: 0.3165 - auc: 0.9811 - val_loss: 0.8184 - val_auc: 0.9059
# Epoch 96/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3107 - auc: 0.9818
# Epoch 96: val_auc did not improve from 0.91582
# 100/100 [==============================] - 670s 7s/step - loss: 0.3107 - auc: 0.9818 - val_loss: 0.8937 - val_auc: 0.8972
# Epoch 97/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3087 - auc: 0.9820
# Epoch 97: val_auc did not improve from 0.91582
# 100/100 [==============================] - 667s 7s/step - loss: 0.3087 - auc: 0.9820 - val_loss: 0.8331 - val_auc: 0.9089
# Epoch 98/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2988 - auc: 0.9830
# Epoch 98: val_auc did not improve from 0.91582
# 100/100 [==============================] - 665s 7s/step - loss: 0.2988 - auc: 0.9830 - val_loss: 0.8200 - val_auc: 0.9103
# Epoch 99/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3160 - auc: 0.9808
# Epoch 99: val_auc did not improve from 0.91582
# 100/100 [==============================] - 666s 7s/step - loss: 0.3160 - auc: 0.9808 - val_loss: 0.7765 - val_auc: 0.9129
# Epoch 100/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2958 - auc: 0.9832
# Epoch 100: val_auc did not improve from 0.91582
# 100/100 [==============================] - 663s 7s/step - loss: 0.2958 - auc: 0.9832 - val_loss: 0.8267 - val_auc: 0.9100

# %% [markdown]
# ### MODEL EVALUATION

# %%
# Summarize history for loss

plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Summarize history for auc

plt.plot(model_history.history['auc'])
plt.plot(model_history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()
